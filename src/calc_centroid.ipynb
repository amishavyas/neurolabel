# %% [markdown]
# # Calculate the Centroid for a Given Parcellation

# %%
import numpy as np
import pandas as pd
from nilearn.datasets import fetch_atlas_schaefer_2018
from nilearn.plotting import find_parcellation_cut_coords
from nilearn.plotting import find_xyz_cut_coords
from nilearn import image
import nibabel as nib
import matplotlib.pyplot as plt
from utils import *
import scipy.ndimage import center_of_mass

# %%
parcellation_path = "~/Code/GitHub/neurolabel/parcellations/neurosynth/Neurosynth_Parcellation_k200.nii.gz"
img = nib.load(parcellation_path)
test = img.get_fdata()
affine
#plt.imshow(test)
#centroid_df = find_parcellation_cut_coords(img, label_hemisphere="right")
#centroid_df2 = find_xyz_cut_coords(img)

# %%
#mask, parc2 = extract_parcel_mask(nifti_file_name=parcellation_path, parcel_num=2)
#centroid_df = find_parcellation_cut_coords(parc2, label_hemisphere="right")

schaefer = fetch_atlas_schaefer_2018()
schaefer_parc = schaefer.maps
# Out:
# [fetch_atlas_schaefer_2018] Dataset directory found: /Users/mundy/nilearn_data/schaefer_2018
